# %%
# Import 需要的套件
import os
import numpy as np
import pandas as pd

# 設定 data_path
dir_data = './data/'

# %%
f_app_train = os.path.join(dir_data, 'application_train.csv')
app_train = pd.read_csv(f_app_train)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline #如果不想要每次在jupyter notebook顯示都寫.show()，可以在jupyter notebook加上%matplotlib inline

# %% [markdown]
# ## 練習時間

# %% [markdown]
# 觀察有興趣的欄位的資料分佈，並嘗試找出有趣的訊息
# #### Eg
# - 計算任意欄位的平均數及標準差
# - 畫出任意欄位的[直方圖](https://zh.wikipedia.org/zh-tw/%E7%9B%B4%E6%96%B9%E5%9B%BE)
#
# ### Hints:
# - [Descriptive Statistics For pandas Dataframe](https://chrisalbon.com/python/data_wrangling/pandas_dataframe_descriptive_stats/)
# - [pandas 中的繪圖函數](https://amaozhao.gitbooks.io/pandas-notebook/content/pandas%E4%B8%AD%E7%9A%84%E7%BB%98%E5%9B%BE%E5%87%BD%E6%95%B0.html)

# %%
app_train.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#               ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# ...

# %%
df = app_train.groupby(by="CODE_GENDER", ).mean()
df
# Out:
#                 SK_ID_CURR    TARGET  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# CODE_GENDER
# F            278235.964094  0.069993      0.392397     156032.309247
# M            278076.627828  0.101419      0.464548     193396.482153
# XNA          200636.500000  0.000000      0.750000     186750.000000
#
#                 AMT_CREDIT   AMT_ANNUITY  AMT_GOODS_PRICE  \
# CODE_GENDER
# F            592766.717305  26304.815242    532406.220509
# M            611095.197084  28657.681177    549942.314404
# XNA          399375.000000  19968.750000    421875.000000
#
#              REGION_POPULATION_RELATIVE    DAYS_BIRTH  DAYS_EMPLOYED  \
# CODE_GENDER
# F                              0.020728 -16502.507177   79693.262759
# M                              0.021138 -15140.050562   33220.412187
# XNA                            0.029672 -13561.250000   -4090.500000
#
#                         ...              FLAG_DOCUMENT_18  FLAG_DOCUMENT_19  \
# CODE_GENDER             ...
# ...

# %%
app_train.select_dtypes(exclude=["object"]).apply(lambda x:np.std(x))
# Out:
# SK_ID_CURR                     102790.008216
# TARGET                              0.272418
# CNT_CHILDREN                        0.722120
# AMT_INCOME_TOTAL               237122.760726
# AMT_CREDIT                     402490.122562
# AMT_ANNUITY                     14493.713748
# AMT_GOODS_PRICE                369445.859292
# REGION_POPULATION_RELATIVE          0.013831
# DAYS_BIRTH                       4363.981536
# DAYS_EMPLOYED                  141275.536810
# DAYS_REGISTRATION                3522.880593
# DAYS_ID_PUBLISH                  1509.447965
# OWN_CAR_AGE                        11.944754
# FLAG_MOBIL                          0.001803
# FLAG_EMP_PHONE                      0.384280
# FLAG_WORK_PHONE                     0.399526
# FLAG_CONT_MOBILE                    0.043164
# FLAG_PHONE                          0.449520
# FLAG_EMAIL                          0.231307
# CNT_FAM_MEMBERS                     0.910680
# REGION_RATING_CLIENT                0.509033
# ...

# %%
df["AMT_INCOME_TOTAL"].plot.bar()
